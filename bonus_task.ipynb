# %% [markdown]
# ## Bonus Task
# ### Shanti Kandel
# ### Data Analytics Fundamentals
# ### 02/18/2023

# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
import warnings
import sqlite3 , csv
import imageio
import nltk

# %%
#loading credit.csv file
df = pd.read_csv("credit.csv")

# %%
#checking the size of the data
df.shape
# Out:
# (1000, 17)

# %%
# checking the variables of the data
df.columns
# Out:
# Index(['checking_balance', 'months_loan_duration', 'credit_history', 'purpose',
#        'amount', 'savings_balance', 'employment_duration', 'percent_of_income',
#        'years_at_residence', 'age', 'other_credit', 'housing',
#        'existing_loans_count', 'job', 'dependents', 'phone', 'default'],
#       dtype='object')

# %%
#head 3 of the data
df.head(3)
# Out:
#   checking_balance  months_loan_duration credit_history               purpose  \
# 0           < 0 DM                     6       critical  furniture/appliances
# 1       1 - 200 DM                    48           good  furniture/appliances
# 2          unknown                    12       critical             education
#
#    amount savings_balance employment_duration  percent_of_income  \
# 0    1169         unknown           > 7 years                  4
# 1    5951        < 100 DM         1 - 4 years                  2
# 2    2096        < 100 DM         4 - 7 years                  2
#
#    years_at_residence  age other_credit housing  existing_loans_count  \
# 0                   4   67         none     own                     2
# 1                   2   22         none     own                     1
# 2                   3   49         none     own                     1
#
#          job  dependents phone default
# 0    skilled           1   yes      no
# ...

# %%
# tail 3 of the data
df.tail(3)
# Out:
#     checking_balance  months_loan_duration credit_history  \
# 997          unknown                    12           good
# 998           < 0 DM                    45           good
# 999       1 - 200 DM                    45       critical
#
#                   purpose  amount savings_balance employment_duration  \
# 997  furniture/appliances     804        < 100 DM           > 7 years
# 998  furniture/appliances    1845        < 100 DM         1 - 4 years
# 999                   car    4576    100 - 500 DM          unemployed
#
#      percent_of_income  years_at_residence  age other_credit housing  \
# 997                  4                   4   38         none     own
# 998                  4                   4   23         none   other
# 999                  3                   4   27         none     own
#
#      existing_loans_count      job  dependents phone default
# 997                     1  skilled           1    no      no
# ...

# %%
# checking all statical value of diffent variables
df.describe()
# Out:
#        months_loan_duration        amount  percent_of_income  \
# count           1000.000000   1000.000000        1000.000000
# mean              20.903000   3271.258000           2.973000
# std               12.058814   2822.736876           1.118715
# min                4.000000    250.000000           1.000000
# 25%               12.000000   1365.500000           2.000000
# 50%               18.000000   2319.500000           3.000000
# 75%               24.000000   3972.250000           4.000000
# max               72.000000  18424.000000           4.000000
#
#        years_at_residence          age  existing_loans_count   dependents
# count         1000.000000  1000.000000           1000.000000  1000.000000
# mean             2.845000    35.546000              1.407000     1.155000
# std              1.103718    11.375469              0.577654     0.362086
# min              1.000000    19.000000              1.000000     1.000000
# ...

# %%
## checking the missing value
df.isna().sum()
# Out:
# checking_balance        0
# months_loan_duration    0
# credit_history          0
# purpose                 0
# amount                  0
# savings_balance         0
# employment_duration     0
# percent_of_income       0
# years_at_residence      0
# age                     0
# other_credit            0
# housing                 0
# existing_loans_count    0
# job                     0
# dependents              0
# phone                   0
# default                 0
# dtype: int64

# %%
# counting different subdata from variable- job
df['job'].value_counts()
# Out:
# skilled       630
# unskilled     200
# management    148
# unemployed     22
# Name: job, dtype: int64

# %%
# counting different subdata from variable - default
df['default'].value_counts()
# Out:
# no     700
# yes    300
# Name: default, dtype: int64

# %%
# counting different subdata from variable from housing 
df['housing'].value_counts()
# Out:
# own      713
# rent     179
# other    108
# Name: housing, dtype: int64

# %%
# counting the number of dependent and independent 
df['dependents'].value_counts()
# Out:
# 1    845
# 2    155
# Name: dependents, dtype: int64

# %% [markdown]
# ## Plotting correlation chart using seaborn mudule function

# %%
# checking the relationship between different variables using correlation function via visualization
plt.figure(figsize =(15,15))
sns.heatmap(df.corr(), annot= True, vmin=1,vmax=1, fmt='.2g')
# Out:
# /var/folders/xk/5xcz5pg57111cdxrsknw5y8r0000gn/T/ipykernel_21179/2266602658.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot= True, vmin=1,vmax=1, fmt='.2g')
# <AxesSubplot: >

# %% [markdown]
# ## Using Imageio module

# %%
## using imageio module to read the image file
img = imageio.imread('IMG_8794 2.JPG')
# Out:
# /var/folders/xk/5xcz5pg57111cdxrsknw5y8r0000gn/T/ipykernel_21179/570926327.py:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning dissapear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   img = imageio.imread('IMG_8794 2.JPG')

# %%
# displaying the image using matplotlib
plt.imshow(img)
plt.show()

# %%
#saving an image
imageio.imwrite('IMG_8794 2.JPG', img)

# %% [markdown]
# ## Using function nltk

# %%
# importing libraries needed to work on nltk
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.sentiment import SentimentIntensityAnalyzer

# %%
# Download NLTK data (only need to do this once)
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/shantikandel/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/shantikandel/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/shantikandel/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/shantikandel/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# Sample text to analyze
text = "dog can be the best human friend."

# %%
text
# Out:
# 'dog can be the best human friend.'

# %%
# Tokenize the text
tokens = word_tokenize(text)

# %%
# Remove stop words
stop_words = set(stopwords.words('english'))
filtered_tokens = [token for token in tokens if token.lower() not in stop_words]

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/shantikandel/nltk_data...
# True

# %%
# Lemmatize the remaining tokens
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]

# %%
# Perform sentiment analysis on the text
analyzer = SentimentIntensityAnalyzer()
scores = analyzer.polarity_scores(text)

# %%
# Print the results
print("Original Text:", text)
print("Tokenized Text:", tokens)
print("Filtered Tokens:", filtered_tokens)
print("Lemmatized Tokens:", lemmatized_tokens)
print("Sentiment Scores:", scores)
# Out:
# Original Text: The quick brown fox jumped over the lazy dog. The dog slept in the sunshine.
# Tokenized Text: ['The', 'quick', 'brown', 'fox', 'jumped', 'over', 'the', 'lazy', 'dog', '.', 'The', 'dog', 'slept', 'in', 'the', 'sunshine', '.']
# Filtered Tokens: ['quick', 'brown', 'fox', 'jumped', 'lazy', 'dog', '.', 'dog', 'slept', 'sunshine', '.']
# Lemmatized Tokens: ['quick', 'brown', 'fox', 'jumped', 'lazy', 'dog', '.', 'dog', 'slept', 'sunshine', '.']
# Sentiment Scores: {'neg': 0.134, 'neu': 0.695, 'pos': 0.171, 'compound': 0.1779}

# %% [markdown]
# ## Using Textstat module

# %%
import textstat

# %%
text_2 = "cat is my best pet animal."
score = textstat.flesch_reading_ease(text)
print(score)
# Out:
# 106.16

# %%
text_2
# Out:
# 'cat is my best pet animal.'

# %% [markdown]
# ## Using the Textblob module

# %%
from textblob import TextBlob

# %%
#  text to analyze
text_3 = "Queen Elizabeth was the most popular royal."

# %%
# Create a TextBlob object from the text
blob = TextBlob(text)

# %%
# Perform sentiment analysis on the text
polarity = blob.sentiment.polarity
subjectivity = blob.sentiment.subjectivity

# %%
# Perform part-of-speech tagging on the text
tags = blob.tags

# %%
# Print the results
print("Original Text:", text)
print("Sentiment Polarity:", polarity)
print("Sentiment Subjectivity:", subjectivity)
print("Part-of-Speech Tags:", tags)
# Out:
# Original Text: dog can be the best human friend.
# Sentiment Polarity: 0.5
# Sentiment Subjectivity: 0.2
# Part-of-Speech Tags: [('dog', 'NN'), ('can', 'MD'), ('be', 'VB'), ('the', 'DT'), ('best', 'JJS'), ('human', 'JJ'), ('friend', 'NN')]
